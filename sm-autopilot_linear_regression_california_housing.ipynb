# %% [markdown]
# # Housing Price Prediction with Amazon SageMaker Autopilot

# %% [markdown]
# ---
#
# This notebook's CI test result for us-west-2 is as follows. CI test results in other regions can be found at the end of the notebook.
#
# ![This us-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-2/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ---

# %% [markdown]
# _**Using Autopilot to Predict House Prices in California**_
#
#
# Kernel `Python 3 (Data Science)` works well with this notebook. You will have the best experience running this within SageMaker Studio.
#
# ---
#
# ## Contents
#
# 1. [Introduction](#Introduction)
# 1. [Setup](#Setup)
# 1. [Prepare Training Data](#Data)
# 1. [Train](#Settingup)
# 1. [Autopilot Results](#Results)
# 1. [Evaluate Using Test Data](#Evaluate)
# 1. [Cleanup](#Cleanup)
#
#
# ---
#
# ## Introduction
#
# Amazon SageMaker Autopilot is an automated machine learning (commonly referred to as AutoML) solution for tabular datasets. You can use SageMaker Autopilot in different ways: on autopilot (without any human input) or with human guidance, without code through SageMaker Studio or scripted using the AWS SDKs. This notebook will use the AWS SDKs to simply create and deploy a machine learning model without doing any feature engineering manually. We will also explore the auto-generated feature importance report.
#
# Predicting housing prices is a classic linear regression problem in ML. The data pertains to the houses found in a given California district (as a group) and include summary stats about them based on census data from 1990. The dataset variables are easily understandable, and the columns are as follows:
#
# * ```longitude```
# * ```latitude```
# * ```housingMedianAge```
# * ```totalRooms```
# * ```totalBedrooms```
# * ```population```
# * ```households```
# * ```medianIncome```
# * ```medianHouseValue``` (target)
#
# What we're going to try to predict is the median house value for a district. We will let Autopilot perform feature engineering, model selection, model tuning, and give us the best candidate model ready to use for inferences.
#
# ---
# ## Setup
#
# _This notebook was created and tested on a ml.t3.medium notebook instance._
#
# Let's start by specifying:
#
# - The S3 bucket and prefix to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting. The following code will use SageMaker's default S3 bucket (and create one if it doesn't exist).
# - The IAM role ARN used to give training and hosting access to your data. See the documentation for how to create these. The following code will use the SageMaker execution role.

# %%
import sagemaker
import boto3
from sagemaker import get_execution_role

region = boto3.Session().region_name

session = sagemaker.Session()

# You can modify the following to use a bucket of your choosing
bucket = session.default_bucket()
prefix = "sagemaker/DEMO-autopilot-housing"

role = get_execution_role()

# This is the client we will use to interact with SageMaker Autopilot
sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# Next, we'll import the Python libraries we'll need for the remainder of the exercise.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
from urllib.parse import urlparse
import time

# %% [markdown]
# ---
# ## Prepare Training Data<a name="Data"></a>
#
# We will use the publicly available California housing dataset. The target variable is the median house value for California districts.
#
# This dataset was obtained from the StatLib repository (http://lib.stat.cmu.edu/datasets/) and derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).

# %%
s3 = boto3.client("s3")
s3.download_file(
    f"sagemaker-example-files-prod-{region}",
    "datasets/tabular/california_housing/cal_housing.tgz",
    "cal_housing.tgz",
)

# %%
# !tar -zxf cal_housing.tgz -o

# %%
columns = [
    "longitude",
    "latitude",
    "housingMedianAge",
    "totalRooms",
    "totalBedrooms",
    "population",
    "households",
    "medianIncome",
    "medianHouseValue",
]

target = "medianHouseValue"

cal_housing_df = pd.read_csv("CaliforniaHousing/cal_housing.data", names=columns, header=None)

# %% [markdown]
# Before starting an Autopilot job, it is good practice to inspect the data to ensure there are no obvious issues with it.

# %%
pd.set_option("display.max_columns", 500)
cal_housing_df
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 0        -122.23     37.88              41.0       880.0          129.0
# 1        -122.22     37.86              21.0      7099.0         1106.0
# 2        -122.24     37.85              52.0      1467.0          190.0
# 3        -122.25     37.85              52.0      1274.0          235.0
# 4        -122.25     37.85              52.0      1627.0          280.0
# ...          ...       ...               ...         ...            ...
# 20635    -121.09     39.48              25.0      1665.0          374.0
# 20636    -121.21     39.49              18.0       697.0          150.0
# 20637    -121.22     39.43              17.0      2254.0          485.0
# 20638    -121.32     39.43              18.0      1860.0          409.0
# 20639    -121.24     39.37              16.0      2785.0          616.0
#
#        population  households  medianIncome  medianHouseValue
# 0           322.0       126.0        8.3252          452600.0
# 1          2401.0      1138.0        8.3014          358500.0
# 2           496.0       177.0        7.2574          352100.0
# 3           558.0       219.0        5.6431          341300.0
# 4           565.0       259.0        3.8462          342200.0
# ...           ...         ...           ...               ...
# 20635       845.0       330.0        1.5603           78100.0
# 20636       356.0       114.0        2.5568           77100.0
# 20637      1007.0       433.0        1.7000           92300.0
# 20638       741.0       349.0        1.8672           84700.0
# 20639      1387.0       530.0        2.3886           89400.0
#
# [20640 rows x 9 columns]

# %% [markdown]
# Notice that the various columns have values in different ranges. For example, values under the target column ```medianHouseValue``` are orders of magnitude higher than other columns. This difference in scale often causes issues when training an ML model, which is why it's a common feature engineering practice to normalize or standardize values (depending on the nature of the numeric distribution and presence of outliers).
#
# However, because Autopilot handles feature engineering automatically (among other things), we're not going to make any analysis or transformations ourselves.
#
# To also illustrate how Autopilot handles data issues, such as missing values, let's introduce some random empty values in our dataset for the housing median age column.

# %%
# Take a small, random sample of the dataset
cal_housing_df_sample = cal_housing_df.sample(frac=0.01, random_state=100)

cal_housing_df["housingMedianAge"].loc[cal_housing_df_sample.index] = (
    cal_housing_df["housingMedianAge"].loc[cal_housing_df_sample.index].apply(lambda row: np.nan)
)
# Out:
# /tmp/ipykernel_241/759799923.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cal_housing_df["housingMedianAge"].loc[cal_housing_df_sample.index] = (

# %% [markdown]
# Now our dataset should contain empty values for ~1% of the rows under the ```housingMedianAge``` column.

# %%
isna_sum = cal_housing_df["housingMedianAge"].isna().sum()
print("{0} values removed from housingMedianAge column".format(isna_sum))
# Out:
# 206 values removed from housingMedianAge column

# %%
# Split data for training and testing (80/20 split)

train_data = cal_housing_df.sample(frac=0.8, random_state=200)

test_data = cal_housing_df.drop(train_data.index)

test_data_no_target = test_data.drop(columns=[target])

# %%
### Upload the dataset to S3

train_file = "train_data.csv"
train_data.to_csv(train_file, index=False, header=True)
train_data_s3_path = session.upload_data(path=train_file, key_prefix=prefix + "/train")
print("Train data uploaded to: " + train_data_s3_path)

test_file = "test_data_no_target.csv"
test_data_no_target.to_csv(test_file, index=False, header=False)
test_data_s3_path = session.upload_data(path=test_file, key_prefix=prefix + "/test")
print("Test data uploaded to: " + test_data_s3_path)
# Out:
# Train data uploaded to: s3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/train/train_data.csv
# Test data uploaded to: s3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/test/test_data_no_target.csv

# %% [markdown]
# ---
# ## Setting up the SageMaker Autopilot Job<a name="Settingup"></a>
#
# After uploading the dataset to Amazon S3, you can invoke Autopilot to find the best ML pipeline to train a model on this dataset.
#
# The required inputs for invoking an Autopilot job are:
# * Amazon S3 location for input dataset and for all output artifacts
# * Name of the target column in the dataset for predictions
# * An IAM role
#
# Currently, Autopilot supports only tabular datasets in CSV format. Either all files should have a header row, or the first file of the dataset, when sorted in alphabetical/lexical order by name, is expected to have a header row.

# %%
input_data_config = [
    {
        "DataSource": {
            "S3DataSource": {
                "S3DataType": "S3Prefix",
                "S3Uri": "s3://{}/{}/train".format(bucket, prefix),
            }
        },
        "TargetAttributeName": target,
    }
]

job_config = {"CompletionCriteria": {"MaxCandidates": 10}}


output_data_config = {"S3OutputPath": "s3://{}/{}/output".format(bucket, prefix)}

# %% [markdown]
# You can also specify the type of problem you want to solve with your dataset (`Regression, MulticlassClassification, BinaryClassification`). In case you are not sure, SageMaker Autopilot will infer the problem type based on statistics of the target column (the column you want to predict).
#
# Because the target attribute, ```medianHouseValue```, is a continuous numeric variable, Autopilot will infer the problem type as regression.
#
# You have the option to limit the running time of a SageMaker Autopilot job by providing either the maximum number of pipeline evaluations or candidates (one pipeline evaluation is called a `Candidate` because it generates a candidate model) or providing the total time allocated for the overall Autopilot job. Under default settings, this job may take several hours to run. This varies between runs because of the nature of the exploratory process Autopilot uses to find optimal training parameters.
#
# For this demo, we limit the number of candidates to 10 so that the job finishes in under 1 hour.
#
# Finally, you also have the option to deploy the winning model to a SageMaker endpoint automatically upon completion. In this case, we will not deploy the endpoint. We'll run a batch prediction job later instead to evaluate our model.
#
# For guidance on how to configure the job parameters, check out the SDK documentation.

# %% [markdown]
# ### Launching the SageMaker Autopilot Job<a name="Launching"></a>
#
# You can now launch the Autopilot job by calling the `create_auto_ml_job` API.

# %%
from time import gmtime, strftime, sleep

timestamp_suffix = strftime("%Y%m%d-%H-%M", gmtime())

auto_ml_job_name = "automl-housing-" + timestamp_suffix
print("AutoMLJobName: " + auto_ml_job_name)

sm.create_auto_ml_job(
    AutoMLJobName=auto_ml_job_name,
    InputDataConfig=input_data_config,
    OutputDataConfig=output_data_config,
    AutoMLJobConfig=job_config,
    # Uncomment to automatically deploy an endpoint
    # ModelDeployConfig={
    #'AutoGenerateEndpointName': True,
    #'EndpointName': 'autopilot-DEMO-housing-' + timestamp_suffix
    # },
    RoleArn=role,
)
# Out:
# AutoMLJobName: automl-housing-20241122-10-48
# {'AutoMLJobArn': 'arn:aws:sagemaker:eu-north-1:418272792897:automl-job/automl-housing-20241122-10-48',
#  'ResponseMetadata': {'RequestId': 'f4e68f98-7fa0-4e8b-819b-fe4dcebfc177',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f4e68f98-7fa0-4e8b-819b-fe4dcebfc177',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '101',
#    'date': 'Fri, 22 Nov 2024 10:48:58 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ---
# The Autopilot job will now be performing the following steps:
#
# * Data Analysis
# * Feature Engineering
# * Model selection
# * Model tuning (hyperparameter optimization)
# * Model feature importance (SageMaker Clarify)

# %% [markdown]
# ### Tracking SageMaker Autopilot job progress

# %%
print("JobStatus - Secondary Status")
print("------------------------------")


describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
print(describe_response["AutoMLJobStatus"] + " - " + describe_response["AutoMLJobSecondaryStatus"])
job_run_status = describe_response["AutoMLJobStatus"]

while job_run_status not in ("Failed", "Completed", "Stopped"):
    describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    job_run_status = describe_response["AutoMLJobStatus"]

    print(
        describe_response["AutoMLJobStatus"] + " - " + describe_response["AutoMLJobSecondaryStatus"]
    )
    sleep(60)
# Out:
# JobStatus - Secondary Status
# ------------------------------
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# InProgress - MergingAutoMLTaskReports
# Completed - Completed

# %% [markdown]
# ---
# ## Results
#
# Now you can use the ```describe_auto_ml_job``` API to look up the best candidate selected by the SageMaker Autopilot job.

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)["BestCandidate"]
best_candidate_name = best_candidate["CandidateName"]

print("\n")
print("CandidateName: " + best_candidate_name)
print(
    "FinalAutoMLJobObjectiveMetricName: "
    + best_candidate["FinalAutoMLJobObjectiveMetric"]["MetricName"]
)
print(
    "FinalAutoMLJobObjectiveMetricValue: "
    + str(best_candidate["FinalAutoMLJobObjectiveMetric"]["Value"])
)
print("\nBest candidate details:: " + str(best_candidate))
# Out:
# CandidateName: automl-housing-20241122-10-48uhh-008-8d102978
# FinalAutoMLJobObjectiveMetricName: validation:mse
# FinalAutoMLJobObjectiveMetricValue: 2872273152.0
#
# Best candidate details:: {'CandidateName': 'automl-housing-20241122-10-48uhh-008-8d102978', 'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:mse', 'Value': 2872273152.0, 'StandardMetricName': 'MSE'}, 'ObjectiveStatus': 'Succeeded', 'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob', 'CandidateStepArn': 'arn:aws:sagemaker:eu-north-1:418272792897:processing-job/automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113', 'CandidateStepName': 'automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:eu-north-1:418272792897:training-job/automl-housing-20241122-10-48-dpp8-1-1f8c0d1f8c1545c4993f8bcf8f', 'CandidateStepName': 'automl-housing-20241122-10-48-dpp8-1-1f8c0d1f8c1545c4993f8bcf8f'}, {'CandidateStepType': 'AWS::SageMaker::TransformJob', 'CandidateStepArn': 'arn:aws:sagemaker:eu-north-1:418272792897:transform-job/automl-housing-20241122-10-48-dpp8-csv-1-3efb4324a7aa490cafe1be', 'CandidateStepName': 'automl-housing-20241122-10-48-dpp8-csv-1-3efb4324a7aa490cafe1be'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:eu-north-1:418272792897:training-job/automl-housing-20241122-10-48uhh-008-8d102978', 'CandidateStepName': 'automl-housing-20241122-10-48uhh-008-8d102978'}], 'CandidateStatus': 'Completed', 'InferenceContainers': [{'Image': '662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/data-processor-models/automl-housing-20241122-10-48-dpp8-1-1f8c0d1f8c1545c4993f8bcf8f/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}, {'Image': '669576153137.dkr.ecr.eu-north-1.amazonaws.com/mxnet-algorithms:inference-cpu', 'ModelDataUrl': 's3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp8-mlp/automl-housing-20241122-10-48uhh-008-8d102978/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'ML_APPLICATION': 'mlp', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv'}}], 'CreationTime': datetime.datetime(2024, 11, 22, 11, 4, 21, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2024, 11, 22, 11, 11, 41, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2024, 11, 22, 11, 18, 9, 592000, tzinfo=tzlocal()), 'CandidateProperties': {'CandidateArtifactLocations': {'Explainability': 's3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/documentation/explainability/output', 'ModelInsights': 's3://sagemaker-eu-north-1-418272792897/sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/documentation/model_monitor/output'}, 'CandidateMetrics': [{'MetricName': 'MSE', 'Value': 2872273152.0, 'Set': 'Validation', 'StandardMetricName': 'MSE'}, {'MetricName': 'MAE', 'Value': 35943.2421875, 'Set': 'Validation', 'StandardMetricName': 'MAE'}, {'MetricName': 'R2', 'Value': 0.7855496406555176, 'Set': 'Validation', 'StandardMetricName': 'R2'}, {'MetricName': 'RMSE', 'Value': 53582.62890625, 'Set': 'Validation', 'StandardMetricName': 'RMSE'}]}}

# %% [markdown]
# If you are curious to explore the performance of other algorithms that Autopilot explored, you can enumerate them via ```list_candidates_for_auto_ml_job``` API call

# %%
sm_dict = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name)
for item in sm_dict["Candidates"]:
    print(item["CandidateName"], item["FinalAutoMLJobObjectiveMetric"])
    print(item["InferenceContainers"][1]["Image"], "\n")
# Out:
# automl-housing-20241122-10-48uhh-010-6af7d113 {'MetricName': 'validation:mse', 'Value': 6174274560.0, 'StandardMetricName': 'MSE'}
# 669576153137.dkr.ecr.eu-north-1.amazonaws.com/linear-learner:inference-cpu
#
# automl-housing-20241122-10-48uhh-005-9995f477 {'MetricName': 'validation:mse', 'Value': 2900049664.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
#
# automl-housing-20241122-10-48uhh-008-8d102978 {'MetricName': 'validation:mse', 'Value': 2872273152.0, 'StandardMetricName': 'MSE'}
# 669576153137.dkr.ecr.eu-north-1.amazonaws.com/mxnet-algorithms:inference-cpu
#
# automl-housing-20241122-10-48uhh-007-2ee6929d {'MetricName': 'validation:mse', 'Value': 4903450624.0, 'StandardMetricName': 'MSE'}
# 669576153137.dkr.ecr.eu-north-1.amazonaws.com/mxnet-algorithms:inference-cpu
#
# automl-housing-20241122-10-48uhh-003-fec16a62 {'MetricName': 'validation:mse', 'Value': 2914976768.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
#
# automl-housing-20241122-10-48uhh-009-940daf4f {'MetricName': 'validation:mse', 'Value': 81908916224.0, 'StandardMetricName': 'MSE'}
# 669576153137.dkr.ecr.eu-north-1.amazonaws.com/linear-learner:inference-cpu
#
# automl-housing-20241122-10-48uhh-002-242e0af7 {'MetricName': 'validation:mse', 'Value': 2919935232.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
#
# automl-housing-20241122-10-48uhh-006-8912bc5e {'MetricName': 'validation:mse', 'Value': 2921854464.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
#
# automl-housing-20241122-10-48uhh-004-136c9fec {'MetricName': 'validation:mse', 'Value': 2969109760.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
#
# automl-housing-20241122-10-48uhh-001-700e328e {'MetricName': 'validation:mse', 'Value': 2884406784.0, 'StandardMetricName': 'MSE'}
# 662702820516.dkr.ecr.eu-north-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3

# %% [markdown]
# ---
# Autopilot automatically generates two executable Jupyter Notebooks:
#
# - ```SageMakerAutopilotDataExplorationNotebook.ipynb```
# - ```SageMakerAutopilotCandidateDefinitionNotebook.ipynb```
#
# These notebooks are stored in S3. Let us download them onto our SageMaker Notebook instance, so we can explore them.

# %%
candidate_nbk = describe_response["AutoMLJobArtifacts"]["CandidateDefinitionNotebookLocation"]
data_explore_nbk = describe_response["AutoMLJobArtifacts"]["DataExplorationNotebookLocation"]


def split_s3_path(s3_path):
    path_parts = s3_path.replace("s3://", "").split("/")
    bucket = path_parts.pop(0)
    key = "/".join(path_parts)
    return bucket, key


s3_bucket, candidate_nbk_key = split_s3_path(candidate_nbk)
_, data_explore_nbk_key = split_s3_path(data_explore_nbk)

print(s3_bucket, candidate_nbk_key, data_explore_nbk_key)

session.download_data(path="./", bucket=s3_bucket, key_prefix=candidate_nbk_key)

session.download_data(path="./", bucket=s3_bucket, key_prefix=data_explore_nbk_key)
# Out:
# sagemaker-eu-north-1-418272792897 sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb
# ['./SageMakerAutopilotDataExplorationNotebook.ipynb']

# %% [markdown]
# #### Data Exploration and Candidate Generation Notebooks

# %% [markdown]
# **Take some time to inspect the Data Exploration notebook. Check the ```Column Analysis and Descriptive Statistics``` section to see the analysis carried out by Autopilot.**

# %% [markdown]
# **Now, take some time to inspect the Candidate Generation notebook. Check the ```Generated Candidates``` section to see the different algorithms and data transformation strategies used by Autopilot.**

# %% [markdown]
# ---
# Autopilot also automatically generates a feature importance report.

# %%
explainability_prefix = best_candidate["CandidateProperties"]["CandidateArtifactLocations"][
    "Explainability"
]

s3_bucket, explainability_dir = split_s3_path(explainability_prefix)

session.download_data(path="./", bucket=s3_bucket, key_prefix=explainability_dir)
# Out:
# ['./automl-housing-20241122-10-48uhh-008-8d102978/analysis.json',
#  './automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/baseline.csv',
#  './automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/out.csv/._SUCCESS.crc',
#  './automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/out.csv/.part-00000-71f91650-0303-4642-85d0-5e6ae986a382-c000.csv.crc',
#  './automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/out.csv/_SUCCESS',
#  './automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/out.csv/part-00000-71f91650-0303-4642-85d0-5e6ae986a382-c000.csv',
#  './automl-housing-20241122-10-48uhh-008-8d102978/report.html',
#  './automl-housing-20241122-10-48uhh-008-8d102978/report.ipynb',
#  './automl-housing-20241122-10-48uhh-008-8d102978/report.pdf']

# %% [markdown]
# The preceding code will download a directory to our local environment. In that directory (the prefix is the autopilot job name, the suffix is automatically generated), you should see the SageMaker Clarify artifacts. SageMaker Clarify provides greater visibility into training data and models to identify and limit bias and explain predictions. The following code will open the feature importance report:

# %%
from IPython.display import IFrame

# Fetch the auto-generated directory name for the SageMaker Clarify artifacts
dir_name = (
    session.list_s3_files(bucket=s3_bucket, key_prefix=explainability_dir)[0]
    .replace(explainability_dir, "")
    .split("/")[1]
)

# Display HTML report
IFrame(src=f"{dir_name}/report.html", width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="automl-housing-20241122-10-48uhh-008-8d102978/report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Your results may vary. But you're likely to see latitude and longitude (i.e., location) on top, along with population size and median income, which are stronger predictors of housing prices than the other features in the dataset.

# %% [markdown]
# In SageMaker Studio, you can also navigate to SageMaker resources tab, click on Experiments and trials, and find your Autopilot experiment. You can double-click on the experiment name to list all trials, and from there you can double-click on a specific trial to see its details, including charts and metrics.

# %% [markdown]
# ---
# ## Evaluate Model Using Test Dataset<a name="Evaluate"></a>

# %% [markdown]
# To evaluate the model on previously unseen data, we will test it against the test dataset we prepared earlier. For that, we don't necessarily need to deploy the model to an endpoint, we can simply run a batch transform job to get predictions for our unlabeled test dataset.

# %% [markdown]
# ### Set up Transform Job

# %%
from sagemaker import AutoML

automl = AutoML.attach(auto_ml_job_name=auto_ml_job_name)

s3_transform_output_path = "s3://{}/{}/inference-results/".format(s3_bucket, prefix)

model_name = "{0}-model".format(best_candidate_name)

model = automl.create_model(
    name=model_name,
    candidate=best_candidate,
)

output_path = s3_transform_output_path + best_candidate_name + "/"

transformer = model.transformer(
    instance_count=1,
    instance_type="ml.m5.xlarge",
    assemble_with="Line",
    strategy="SingleRecord",
    output_path=output_path,
    env={"SAGEMAKER_MODEL_SERVER_TIMEOUT": "100", "SAGEMAKER_MODEL_SERVER_WORKERS": "1"},
)

# %% [markdown]
# ### Launch Transform Job

# %%
transformer.transform(
    data=test_data_s3_path,
    split_type="Line",
    content_type="text/csv",
    wait=False,
    model_client_config={"InvocationsTimeoutInSeconds": 80, "InvocationsMaxRetries": 1},
)

print("Starting transform job {}".format(transformer._current_job_name))
# Out:
# INFO:sagemaker:Creating transform job with name: automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368
# Starting transform job automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368

# %% [markdown]
# #### Track Transform Job Status

# %%
## Wait for jobs to finish
pending_complete = True
job_name = transformer._current_job_name

while pending_complete:
    pending_complete = False

    description = sm.describe_transform_job(TransformJobName=job_name)
    if description["TransformJobStatus"] not in ["Failed", "Completed"]:
        pending_complete = True

    print("{} transform job is running.".format(job_name))
    time.sleep(60)

print("\nCompleted.")
# Out:
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
# automl-housing-20241122-10-48uhh-008-8d-2024-11-22-11-29-35-368 transform job is running.
#
# Completed.

# %% [markdown]
# ### Evaluate the Inference Results

# %% [markdown]
# The transform job will have now generated a CSV file with inference results for the test dataset. We will use those results and compare them with the real test labels to see how the model performs compared to real data.

# %%
def get_csv_from_s3(s3uri, file_name):
    parsed_url = urlparse(s3uri)
    bucket_name = parsed_url.netloc
    prefix = parsed_url.path[1:].strip("/")
    s3 = boto3.resource("s3")
    obj = s3.Object(bucket_name, "{}/{}".format(prefix, file_name))
    return obj.get()["Body"].read().decode("utf-8")


job_status = sm.describe_transform_job(TransformJobName=job_name)["TransformJobStatus"]

if job_status == "Completed":
    pred_csv = get_csv_from_s3(transformer.output_path, "{}.out".format(test_file))
    predictions = pd.read_csv(io.StringIO(pred_csv), header=None)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt


labels_df = test_data[target]
mse = mean_squared_error(labels_df, predictions)
rmse = sqrt(mse)

print("MSE: {0}\nRMSE: {1}".format(mse, rmse))

# Compute regression metrics
r2 = r2_score(labels_df, predictions)
mae = mean_absolute_error(labels_df, predictions)

print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# MSE: 2589663883.845235
# RMSE: 50888.74024620019
# R-squared: 0.8000507225409288
# Mean Absolute Error: 34705.99728701096

# %% [markdown]
# ---
# ## Cleanup
#
# The Autopilot job creates many underlying artifacts such as dataset splits, preprocessing scripts, or preprocessed data, etc. This code, when un-commented, deletes them.

# %%
s3 = boto3.resource("s3")
s3_bucket = s3.Bucket(bucket)

print(s3_bucket)
job_outputs_prefix = "{}/output/{}".format(prefix, auto_ml_job_name)
print(job_outputs_prefix)

# Delete S3 objects
s3_bucket.objects.filter(Prefix=job_outputs_prefix).delete()
# Out:
# s3.Bucket(name='sagemaker-eu-north-1-418272792897')
# sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48
# [{'ResponseMetadata': {'RequestId': 'ZHDQ22Q4SXR9W96K',
#    'HostId': 'MQ9qEWnqlCnkr8DEJxGKlU80t7hTvbWPGQK/W8bN5BbigtBpG6t9/ZFHBmwzk6oZzYFninbHgvG+f7uBTGVD4SroyXBRufv6',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'MQ9qEWnqlCnkr8DEJxGKlU80t7hTvbWPGQK/W8bN5BbigtBpG6t9/ZFHBmwzk6oZzYFninbHgvG+f7uBTGVD4SroyXBRufv6',
#     'x-amz-request-id': 'ZHDQ22Q4SXR9W96K',
#     'date': 'Fri, 22 Nov 2024 11:57:42 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/data-processor-models/automl-housing-20241122-10-48-dpp3-1-d5c03e1aa4b84b6e8ad51e17c5/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_34.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/README.md'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/candidate_data_processors/dpp1.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/documentation/explainability/output/automl-housing-20241122-10-48uhh-008-8d102978/explanations_shap/baseline.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_14.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/sagemaker_automl/interactive_runner.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_59.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_64.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_7.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/validation/chunk_16.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_74.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/candidate_data_processors/sagemaker_serve.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_76.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/data-processor-models/automl-housing-20241122-10-48-dpp9-1-0e06b52e1aa049a7a7f5cce8af/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_10.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_33.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/validation/chunk_9.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_24.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_32.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/documentation/explainability/output/automl-housing-20241122-10-48uhh-008-8d102978/report.html'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_71.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/MANIFEST.in'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/validation/chunk_0.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/candidate_data_processors/trainer.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_39.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/validation/chunk_14.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_40.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_8.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_19.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_73.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_70.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_46.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_12.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_38.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_55.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_36.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_16.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/explainability_samples/sample.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp0/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_37.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/preprocessed-data/tuning_data/train/chunk_28.csv'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp4/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/generated_module/candidate_data_processors/dpp4.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp5/rpb/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp7/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp2/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/sagemaker-automl-candidates/automl-housing-20241122-10-48-pr-1-19b92280d9af41d895c6dfc7544c/notebooks/sagemaker_automl/config.py'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp1/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp3/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp6/rpb/validation/chunk_2.csv.out'},
# ...
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp7-xgb/automl-housing-20241122-10-48uhh-003-fec16a62/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp5-ll/automl-housing-20241122-10-48uhh-009-940daf4f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp2-xgb/automl-housing-20241122-10-48uhh-005-9995f477/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp3-xgb/automl-housing-20241122-10-48uhh-004-136c9fec/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp3-xgb/automl-housing-20241122-10-48uhh-004-136c9fec/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp6-xgb/automl-housing-20241122-10-48uhh-006-8912bc5e/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp8-mlp/automl-housing-20241122-10-48uhh-007-2ee6929d/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp7-xgb/automl-housing-20241122-10-48uhh-003-fec16a62/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp5-ll/automl-housing-20241122-10-48uhh-010-6af7d113/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp5-ll/automl-housing-20241122-10-48uhh-009-940daf4f/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp8-mlp/automl-housing-20241122-10-48uhh-008-8d102978/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp5-ll/automl-housing-20241122-10-48uhh-010-6af7d113/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp6-xgb/automl-housing-20241122-10-48uhh-002-242e0af7/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/tuning/automl-hou-dpp6-xgb/automl-housing-20241122-10-48uhh-006-8912bc5e/output/output.tar.gz'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp8/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-autopilot-housing/output/automl-housing-20241122-10-48/transformed-data/dpp9/csv/train/chunk_62.csv.out'}]}]

# %% [markdown]
# We then delete all the experiment and model resources created by the Autopilot experiment.

# %%
def cleanup_experiment_resources(experiment_name):
    trials = sm.list_trials(ExperimentName=experiment_name)["TrialSummaries"]
    print("TrialNames:")
    for trial in trials:
        trial_name = trial["TrialName"]
        print(f"\n{trial_name}")

        components_in_trial = sm.list_trial_components(TrialName=trial_name)
        print("\tTrialComponentNames:")
        for component in components_in_trial["TrialComponentSummaries"]:
            component_name = component["TrialComponentName"]
            print(f"\t{component_name}")
            sm.disassociate_trial_component(TrialComponentName=component_name, TrialName=trial_name)
            try:
                # comment out to keep trial components
                sm.delete_trial_component(TrialComponentName=component_name)
            except:
                # component is associated with another trial
                continue
            # to prevent throttling
            time.sleep(5)
        sm.delete_trial(TrialName=trial_name)
    sm.delete_experiment(ExperimentName=experiment_name)
    print(f"\nExperiment {experiment_name} deleted")


def cleanup_autopilot_models(autopilot_job_name):
    print("{0}:\n".format(autopilot_job_name))
    response = sm.list_models(NameContains=autopilot_job_name)

    for model in response["Models"]:
        model_name = model["ModelName"]
        print(f"\t{model_name}")
        sm.delete_model(ModelName=model_name)
        # to prevent throttling
        time.sleep(3)

# %%
cleanup_experiment_resources("{0}-aws-auto-ml-job".format(auto_ml_job_name))
# Out:
# TrialNames:
#
# automl-housing-20241122-10-48uhh-001-700e328e-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-001-700e328e-aws-training-job
# 	automl-housing-20241122-10-48-dpp2-rpb-1-40398532976646d88b3d51-aws-transform-job
# 	automl-housing-20241122-10-48-dpp2-1-2c1777e77ce640bb995a87a5d6-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-006-8912bc5e-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-006-8912bc5e-aws-training-job
# 	automl-housing-20241122-10-48-dpp6-rpb-1-f925c550e77149d29e7526-aws-transform-job
# 	automl-housing-20241122-10-48-dpp6-1-7d9d16ad38504b7bb170557234-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-007-2ee6929d-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-007-2ee6929d-aws-training-job
# 	automl-housing-20241122-10-48-dpp8-csv-1-3efb4324a7aa490cafe1be-aws-transform-job
# 	automl-housing-20241122-10-48-dpp8-1-1f8c0d1f8c1545c4993f8bcf8f-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-005-9995f477-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-005-9995f477-aws-training-job
# 	automl-housing-20241122-10-48-dpp2-rpb-1-40398532976646d88b3d51-aws-transform-job
# 	automl-housing-20241122-10-48-dpp2-1-2c1777e77ce640bb995a87a5d6-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-003-fec16a62-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-003-fec16a62-aws-training-job
# 	automl-housing-20241122-10-48-dpp7-rpb-1-6859ba9642bb4c20971601-aws-transform-job
# 	automl-housing-20241122-10-48-dpp7-1-53c8c5c7e26d43c996439a3243-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-002-242e0af7-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-002-242e0af7-aws-training-job
# 	automl-housing-20241122-10-48-dpp6-rpb-1-f925c550e77149d29e7526-aws-transform-job
# 	automl-housing-20241122-10-48-dpp6-1-7d9d16ad38504b7bb170557234-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-004-136c9fec-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-004-136c9fec-aws-training-job
# 	automl-housing-20241122-10-48-dpp3-rpb-1-9ff5f062c1d34d5f877333-aws-transform-job
# 	automl-housing-20241122-10-48-dpp3-1-d5c03e1aa4b84b6e8ad51e17c5-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-009-940daf4f-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-009-940daf4f-aws-training-job
# 	automl-housing-20241122-10-48-dpp5-rpb-1-e4d93de4abf24b9697ba83-aws-transform-job
# 	automl-housing-20241122-10-48-dpp5-1-220723fb2db54a139bb1436f1c-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-008-8d102978-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-008-8d102978-aws-training-job
# 	automl-housing-20241122-10-48-dpp8-csv-1-3efb4324a7aa490cafe1be-aws-transform-job
# 	automl-housing-20241122-10-48-dpp8-1-1f8c0d1f8c1545c4993f8bcf8f-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# automl-housing-20241122-10-48uhh-010-6af7d113-aws-trial
# 	TrialComponentNames:
# 	automl-housing-20241122-10-48uhh-010-6af7d113-aws-training-job
# 	automl-housing-20241122-10-48-dpp5-rpb-1-e4d93de4abf24b9697ba83-aws-transform-job
# 	automl-housing-20241122-10-48-dpp5-1-220723fb2db54a139bb1436f1c-aws-training-job
# 	automl-housing-20241122-10-48-db-1-388c4cafd2ce4d01b157ed3a6113-aws-processing-job
#
# Experiment automl-housing-20241122-10-48-aws-auto-ml-job deleted

# %%
cleanup_autopilot_models(auto_ml_job_name)
# Out:
# automl-housing-20241122-10-48:
#
# 	automl-housing-20241122-10-48uhh-008-8d102978-model
# 	automl-housing-20241122-10-48-dpp7-model-dce5b82bace74ce9955ec4
# 	automl-housing-20241122-10-48-dpp9-model-eddca3f87a4d4d9ea4cf40
# 	automl-housing-20241122-10-48-dpp0-model-328b00dbc15b403db38d09
# 	automl-housing-20241122-10-48-dpp8-model-7facc8c8fe8c4362a3c547
# 	automl-housing-20241122-10-48-dpp6-model-14b8336aa7cb40c699cd43
# 	automl-housing-20241122-10-48-dpp1-model-4dfdc83ba06941a58a1467
# 	automl-housing-20241122-10-48-dpp3-model-74f5af7b24d641f59eb1f5
# 	automl-housing-20241122-10-48-dpp5-model-4633d30ea0a748e8a96238
# 	automl-housing-20241122-10-48-dpp4-model-0c768a6e242d46098c48da

# %% [markdown]
# Finally, the following code, when uncommented, will delete the local files used in this demo.

# %%
import shutil
import glob
import os


def delete_local_files():
    base_path = ""
    dir_list = glob.iglob(os.path.join(base_path, "{0}*".format(auto_ml_job_name)))

    for path in dir_list:
        if os.path.isdir(path):
            shutil.rmtree(path)

    if os.path.exists("CaliforniaHousing"):
        shutil.rmtree("CaliforniaHousing")

    if os.path.exists("cal_housing.tgz"):
        os.remove("cal_housing.tgz")

    if os.path.exists("SageMakerAutopilotCandidateDefinitionNotebook.ipynb"):
        os.remove("SageMakerAutopilotCandidateDefinitionNotebook.ipynb")

    if os.path.exists("SageMakerAutopilotDataExplorationNotebook.ipynb"):
        os.remove("SageMakerAutopilotDataExplorationNotebook.ipynb")

    if os.path.exists("test_data_no_target.csv"):
        os.remove("test_data_no_target.csv")

    if os.path.exists("test_data.csv"):
        os.remove("test_data.csv")

    if os.path.exists("train_data.csv"):
        os.remove("train_data.csv")


## UNCOMMENT TO CLEAN UP LOCAL FILES
# delete_local_files()

# %% [markdown]
# **Note: If you enabled automatic endpoint creation, you will need to delete the endpoint manually.**

# %% [markdown]
# ## Notebook CI Test Results
#
# This notebook was tested in multiple regions. The test results are as follows, except for us-west-2 which is shown at the top of the notebook.
#
# ![This us-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This us-east-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-2/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This us-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ca-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ca-central-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This sa-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/sa-east-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This eu-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This eu-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-2/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This eu-west-3 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-3/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This eu-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-central-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This eu-north-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-north-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ap-southeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ap-southeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-2/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ap-northeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ap-northeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-2/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
#
# ![This ap-south-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-south-1/end_to_end_ml_lifecycle|sm-autopilot_linear_regression_california_housing.ipynb)
